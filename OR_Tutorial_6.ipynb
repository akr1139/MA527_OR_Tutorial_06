# %% [markdown]
# <a href="https://colab.research.google.com/github/akr1139/MA527_OR_Tutorial_06/blob/main/OR_Tutorial_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $$
# \text { Consider source }=1
# $$

# %% [markdown]
# $$
# \begin{aligned}
# &\text { Initial Distance d }\\
# &\begin{array}{|l|l|l|l|l|l|l|}
# \hline 0 & 6 & 5 & 5 & \alpha & \alpha & \alpha \\
# \hline
# \end{array}
# \end{aligned}
# $$

# %% [markdown]
# $$
# \begin{aligned}
# &\text { Initial Distance } \mathrm{d}\\
# &\begin{array}{|c|c|c|c|c|c|c|c|}
# \hline   _1 & _2 & _3 & _4 & _5 & _6 & _7 \\
# \hline   0 & 6 & 5 & 5 & \alpha & \alpha & \alpha \\
# \hline   \alpha & 0 & \alpha & \alpha & -1 & \alpha & \alpha \\
# \hline   \alpha & -2 & 0 & \alpha & 1 & \alpha & \alpha \\
# \hline   \alpha & \alpha & -2 & 0 & \alpha & -1 & \alpha \\
# \hline   \alpha & \alpha & \alpha & \alpha & 0 & \alpha & 3 \\
# \hline   \alpha & \alpha & \alpha & \alpha & \alpha & 0 & 3 \\
# \hline   \alpha & \alpha & \alpha & \alpha & \alpha & \alpha & 0 \\
# \hline
# \end{array}
# \end{aligned}
# $$
